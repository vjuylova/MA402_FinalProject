# %%
import importlib
import elastic2D_SOLVER
importlib.reload(elastic2D_SOLVER)
from elastic2D_SOLVER import ElasticitySolver

# %%
solver = ElasticitySolver(
    nx=32,
    ny=32,
    mu=1.0,
    lam=1.0,
    body_force=[0.0, -9.8]
)

u = solver.solve()
solver.plot_solution(u)
solver.plot_deformed(u, scale=10.0)
# Out:
# Elasticity Solver | mesh 32x32 | DOFs=2178
